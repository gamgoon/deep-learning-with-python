# %%
import numpy as np

# 다른 온도 값을 사용하여 확률 분포의 가중치 바꾸기
# original_distribution 은 전체 합이 1인 1D 넘파이 배열
# temperature는 출력 분포의 엔트로피 양을 결정
def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    # 원본 분포의 가중치를 변경하며 반환. 
    # 이 분포의 합은 1이 아닐 수 있으므로 새로운 분포의 합으로 나눈다.
    return distribution / np.sum(distribution)

# %%
# 글자 수준의 LSTM 텍스트 생성 모델 구현

#데이터 전처리
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 말뭉치 크기: 600893

# %%
# 글자 시퀀스 벡터화
maxlen = 60 # 60개의 글자로 된 시퀀스를 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링

sentences = [] # 추출한 시퀀스
next_chars = [] # 타깃(시퀀스 다음 글자)

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자 리스트
print('고유한 글자:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑

print('벡터화...')
# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꾼다.
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %%
y[0]
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
print(len(sentences))
# Out:
# 60

# %%
print(next_chars)
# Out:
# ['r', 'n', ' ', 'o', 'd', 'o', 's', 'p', 't', 'g', 'h', ' ', 'l', 'h', 'o', 'p', 'r', ' ', ' ', ' ', 'r', 's', 'h', ' ', 'v', 'b', 'n', 'o', 'a', 's', ',', 'a', ' ', 'i', 'd', 'o', 'n', 'r', 'a', ' ', 'm', '-', 'h', ' ', 'e', 'e', 'i', 'e', 'e', 'o', 'n', 's', 'n', 'c', 'm', ' ', 'p', 't', 'i', ' ', 't', 'w', 'c', 't', 'y', 'a', ' ', 'u', 'l', 'p', 'd', 'h', 'r', 'd', 'e', 'e', 't', 't', 't', ' ', 'v', 'b', 'n', 'n', 'i', 'e', 'a', ' ', 's', 'm', ' ', 't', 'd', 'f', '\n', 'n', 'n', 'a', 'o', 'n', 'c', 't', 'n', ' ', 'e', 'a', 'n', 'e', 'a', 'o', 'd', 'e', 'e', ' ', ' ', ' ', 'n', 'a', '\n', ' ', 'e', 'n', 'e', 'r', 'k', 'd', 'f', 'o', 'a', 't', 'd', 'w', 'h', 'a', 'a', ' ', 's', 'u', 'g', ' ', 'e', '-', ',', 'n', 'e', ' ', ' ', 'a', 's', 't', 'l', ' ', 'r', 'h', 'e', 'r', 's', 'f', 'r', 'w', ' ', 'i', 'a', ' ', 'a', 'i', 'h', ' ', 'l', 'n', 't', 't', 'l', 'd', 'm', 'l', 's', 'n', 'h', 'g', 'u', '-', 'a', 'm', 'e', 't', 't', 't', 's', 't', 't', 'l', 't', 'a', '.', 'u', 't', 's', 'a', 's', 'i', 's', ',', 'h', 'e', 'r', 'g', 'd', 'r', 'n', ' ', 'r', 'o', 'n', 't', 't', 'l', 'd', 'm', 'i', 'n', 'i', 'p', 'l', 'o', 'y', 'w', 't', 'e', 's', 'e', ',', 'h', 'e', 'r', 'o', 'l', 'i', '\n', 'd', 'e', 'd', ' ', 'r', 'i', 'h', ' ', 's', 'e', ' ', 'y', 'a', ' ', 'e', 'o', 'y', ' ', 'b', ' ', 'e', 'l', 'm', 'n', 't', 'o', 's', ' ', 'd', 'r', 'a', 'y', 'h', 't', 'e', 's', 't', 'a', ' ', 'e', 'i', 'w', 'l', 'e', 'n', '\n', 'd', 'g', 'n', 'n', 'r', 'o', ' ', 'a', 'h', ' ', 't', 'l', ' ', 'f', 'c', ' ', 'r', 'h', 'b', 'i', 'o', 's', 'h', 'm', 's', 'g', 'n', 'a', 'o', 't', 'p', 'l', 'o', 'i', 'l', 'd', 'i', 's', 's', 'h', 'd', 'm', 'i', 's', 'a', '\n', 't', 'r', ' ', 'a', 'd', 'p', 'h', 's', 'o', ' ', 'p', 'a', 's', 'e', 't', 'i', ' ', ' ', 'm', 'o', 'a', 't', 'e', 's', 'h', 's', 'h', 's', 'l', 'u', 'r', 'i', 'o', ' ', 'i', ',', 'n', 'h', 'f', 'm', 'f', 'u', 'e', '-', 'n', 'e', '-', 'p', 's', 't', 'n', 'h', ' ', 't', 'e', 'c', 's', ' ', 'i', ' ', 's', 'i', ')', 'p', 'h', 's', 'o', '\n', 'a', 'u', 'n', 'o', 's', 'a', 'e', 'p', 'o', 'o', 't', ' ', 'r', 'o', 'g', 'm', 'r', 'o', 'a', 'a', 'a', 'o', ' ', 'n', 'a', 'z', 'i', ' ', ' ', 'r', 'r', 't', 'c', 'd', 'v', 'y', 'e', 'o', 'l', 'v', 'y', 'u', 'n', 'a', '-', 'o', 'u', 'n', 'a', 's', 't', ' ', 'i', 's', 'h', 'o', 't', ' ', 'g', 't', 't', ' ', ' ', ' ', '\n', ' ', 'p', ',', 'a', 'o', 'y', ' ', 'o', 's', 'f', ' ', 'o', 'a', 's', 'f', 'e', 's', 'f', 'r', 'r', ',', 's', 'a', 'a', 'r', 'o', ' ', ' ', 'i', ' ', 'r', 'e', 't', 'e', ' ', ' ', 'e', 'e', 'i', ' ', ' ', 'i', ' ', 'o', 'b', ' ', 'r', 'l', 'o', ',', 'o', ',', 'c', 'e', 's', ' ', 'd', 'a', 'e', 'e', 'a', ' ', 'e', 's', 'n', 't', 'n', 'n', 'n', 'a', 'u', ' ', 'i', 'c', 'h', 'h', 't', ' ', ' ', 'e', 'o', 't', 'a', ' ', ' ', 's', 's', 'e', 't', 'r', 't', 'a', '\n', 'e', 'n', 'o', ' ', ' ', 'i', 'a', ' ', 'y', ',', 'h', 'g', 'n', 's', 'l', 'o', 'a', 'h', 'e', 'u', '.', 't', 'e', 's', 'h', ' ', ' ', 'd', ' ', ' ', 's', 'i', ' ', 'e', 'e', 'e', 'u', 'n', 'h', 'h', 'r', 'o', 'h', 'a', 't', 'w', 'h', 'v', 'l', 't', 'g', 'l', 'm', ' ', 'l', 'r', 't', 'h', 'g', 'h', 'e', 'i', 't', 'o', 'a', 'e', 'a', 'u', 't', '\n', 'r', ' ', ' ', 'o', 'o', ' ', 'd', 'w', 'i', 'p', 'i', ' ', 'r', 'a', 'r', ':', 'o', 'a', 'c', 'h', 'o', 'p', ' ', 's', 'e', ' ', 'c', 'i', 't', 'e', 'f', 'h', ' ', 'n', '-', 'r', 'n', 'a', 'e', 't', ' ', 'd', 't', 'd', 't', 'n', 'i', 'a', 'a', 'a', ' ', 'a', 'n', 'm', 'n', 'u', 'p', ' ', 't', 's', 'o', 'b', 'u', 'r', 'e', 'l', 'o', 't', 'a', 'h', 'g', 'i', 'm', 't', 'e', 'a', 'l', 'b', 'c', 'f', 's', ' ', 'a', 't', ' ', 'r', ',', 'h', 'm', 't', 'i', 's', 'e', 'a', ' ', 'e', 'o', ' ', 'n', 'r', 's', 'f', 'r', 'r', 'h', 'h', 't', 'h', ' ', 'e', 'a', 'o', 'a', 's', 'e', 'o', '-', 'm', 'y', 'p', 't', 's', 'n', 'n', 'o', 'o', 'p', 'e', 'p', 'i', 'a', ' ', 'e', 'o', ' ', ' ', 's', 'f', 'b', ' ', 'w', 'h', ' ', ' ', 's', 'e', ' ', 'r', 'u', 'e', ' ', 'e', 'e', 'o', ',', 'i', 'o', 't', 's', 'i', 't', 'r', '\n', 'n', 'g', 'n', 'r', ' ', 'e', 'h', 'r', ...

# %%
# 네트워크 구성
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 텍스트 생성 루프
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60): # 60 에포크 동안 모델을 훈련
    print('에포크', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    
    seed_text = text[start_index: start_index + maxlen] # 무작위로 시드 텍스트를 선택
    print('--- 시드 텍스트: "' + seed_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]: # 여러가지 샘플링 온도 시도
        print('---- 온도: ', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자를 생성한다
            # 지금까지 생성한 글자를 원-핫 인코딩으로 바꾼다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            # 다음 글자를 샘플링한다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# Epoch 1/1
# 200278/200278 [==============================] - 222s 1ms/step - loss: 1.8861
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ---- 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the says the existions and not the say, and the suppicience of the man and some of the sense the self-conservent of the same and the present of the man and some of the strenged the man and the disconcess and the same of the conserves the greater the more spirition of the more some of the man and the present of the present of the same of the says the says the say, the se
# ---- 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for the ofe science are the one of the cale and disconcessibles the exisint of the present and the eneselly discordinged and of the conserves the generation, there double instinction the existions and fallives of men that the rearady a concence of the and sould to the conserving of the sense and being and convertions of the lad what he leows for the mans of the depter the gadery pain the farther do
# ---- 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through for thas same-gen are who assiving of as londing and pridition! which for the listive of which of fout- deganions of herdar for the
# one varmals percicion a
#   dowed his wased is he recepes--which--in been word and its deink at tar, and timed of proicever, instinces able there self here to
# muld prearaties." in indeptions
# man-repertity in sporat induperxantary thereby as there freeds, . some by prefici
# ---- 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for thereinadifice there
# pholaps
# anding, a sgrfentredr with
# the great as profapen, nhe klatisg, bestaid theirstitly, hencelufching with, we rate, conscemmenlemmour" inwensiatefler.
# though
# tuliging has load fars thraw cincentabical moralme
# oritic, not ord toble ex
# eccanclifing, tye, onlly nowlaid it sexuadont the doomscien; everythrieed madifical ad:
# trounto--conventimate vilian !o
# is feal conceman!,
# 에포크 2
# Epoch 1/1
# 200278/200278 [==============================] - 231s 1ms/step - loss: 1.6457
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ---- 온도:  0.2
# the slowly ascending ranks and classes, in which,
# through for the present may a surface of the present and the interest of the present with the same the same the same of the same the say the man and such the surence of the self temest of the surence and such the self-be life the same the only and such a power and the same interest that the same the man the sense of his present the present and something and the self-things and the same to the same the soul
# ---- 온도:  0.5
# the slowly ascending ranks and classes, in which,
# through for that the self as it metic of the interest as a doubt things the more of himself of his present the present appression and the present man
# ---- 온도:  1.0
# the slowly ascending ranks and classes, in which,
# through formenomises from a miyst
# to a life as
# in
# matters.
#
#
# 1yoton the fore!" to is from this his sorr, as uncectionst, virtues: "the temptlys? the gleid: but germaniousness, exception of his folloe.
#
# clans famely insticys it, he luthsth of the symething first, chass, it serstanic have degards
# the figate
# which soulss. in himself more lives whose herochaps develonsity to ma"ter wark
# just mankind , not houg
# ---- 온도:  1.2
# the slowly ascending ranks and classes, in which,
# through for gentu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-2de4e7599419> in <module>()
#      25
#      26             # 다음 글자를 샘플링한다
# ---> 27             preds = model.predict(sampled, verbose=0)[0]
#      28             next_index = sample(preds, temperature)
#      29             next_char = chars[next_index]
#
# ~/development/virtualenv/python3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/development/virtualenv/python3/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/development/virtualenv/python3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/development/virtualenv/python3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/development/virtualenv/python3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:
